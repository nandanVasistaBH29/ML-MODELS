# %%
import pandas as pd
from sklearn.datasets import load_wine
wine = load_wine()

# %%
dir(wine)
# Out:
# ['DESCR', 'data', 'feature_names', 'frame', 'target', 'target_names']

# %%
df = pd.DataFrame(wine.data,columns=wine.feature_names)
df
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0      14.23        1.71  2.43               15.6      127.0           2.80
# 1      13.20        1.78  2.14               11.2      100.0           2.65
# 2      13.16        2.36  2.67               18.6      101.0           2.80
# 3      14.37        1.95  2.50               16.8      113.0           3.85
# 4      13.24        2.59  2.87               21.0      118.0           2.80
# ..       ...         ...   ...                ...        ...            ...
# 173    13.71        5.65  2.45               20.5       95.0           1.68
# 174    13.40        3.91  2.48               23.0      102.0           1.80
# 175    13.27        4.28  2.26               20.0      120.0           1.59
# 176    13.17        2.59  2.37               20.0      120.0           1.65
# 177    14.13        4.10  2.74               24.5       96.0           2.05
#
# ...

# %%
wine.target_names
# Out:
# array(['class_0', 'class_1', 'class_2'], dtype='<U7')

# %%
df['target'] = wine.target

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(wine.data,wine.target,test_size=0.2)

# %%
from sklearn.naive_bayes import GaussianNB, MultinomialNB
model = GaussianNB()
model.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
model.score(x_test,y_test)
# Out:
# 0.9722222222222222

# %%
mn = MultinomialNB()
mn.fit(x_train,y_train)
mn.score(x_test,y_test)
# Out:
# 0.8888888888888888

# %% [markdown]
# lets do clustering

# %%
from sklearn.cluster import KMeans
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
df
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0      14.23        1.71  2.43               15.6      127.0           2.80
# 1      13.20        1.78  2.14               11.2      100.0           2.65
# 2      13.16        2.36  2.67               18.6      101.0           2.80
# 3      14.37        1.95  2.50               16.8      113.0           3.85
# 4      13.24        2.59  2.87               21.0      118.0           2.80
# ..       ...         ...   ...                ...        ...            ...
# 173    13.71        5.65  2.45               20.5       95.0           1.68
# 174    13.40        3.91  2.48               23.0      102.0           1.80
# 175    13.27        4.28  2.26               20.0      120.0           1.59
# 176    13.17        2.59  2.37               20.0      120.0           1.65
# 177    14.13        4.10  2.74               24.5       96.0           2.05
#
# ...

# %%
scalar = MinMaxScaler()
scalar.fit(df.alcohol)
df.alcohol=scalar.transform(df.alcohol)
scalar.fit(df.malic_acid)
df.malic_acid=scalar.transform(df.malic_acid)
scalar.fit(df.ash)
df.ash=scalar.transform(df.ash)
scalar.fit(df.alcalinity_of_ash)
df.alcalinity_of_ash=scalar.transform(df.alcalinity_of_ash)

scalar.fit(df.magnesium)
df.magnesium=scalar.transform(df.magnesium)
scalar.fit(df.total_phenols)
df.total_phenols=scalar.transform(df.total_phenols)

scalar.fit(df.flavanoids)
df.flavanoids=scalar.transform(df.flavanoids)
scalar.fit(df.proanthocyanins)
df.proanthocyanins=scalar.transform(df.proanthocyanins)

scalar.fit(df.color_intensity)
df.color_intensity=scalar.transform(df.color_intensity)
scalar.fit(df.hue)
df.hue=scalar.transform(df.hue)

scalar.fit(df.proline)
df.proline=scalar.transform(df.proline)

df.drop(df[['od280/od315_of_diluted_wines']])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [36], in <cell line: 2>()
#       1 scalar = MinMaxScaler()
# ----> 2 scalar.fit(df.alcohol)
#       3 df.alcohol=scalar.transform(df.alcohol)
#       4 scalar.fit(df.malic_acid)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_data.py:416, in MinMaxScaler.fit(self, X, y)
#     414 # Reset internal state before fitting
#     415 self._reset()
# --> 416 return self.partial_fit(X, y)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_data.py:453, in MinMaxScaler.partial_fit(self, X, y)
#     447     raise TypeError(
#     448         "MinMaxScaler does not support sparse input. "
#     449         "Consider using MaxAbsScaler instead."
#     450     )
#     452 first_pass = not hasattr(self, "n_samples_seen_")
# --> 453 X = self._validate_data(
#     454     X,
# ...
