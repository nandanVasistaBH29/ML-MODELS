# %%
import pandas as pd
df=pd.read_csv("weather.csv")
df
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0        8.0     24.3       0.0          3.4       6.3          NW
# 1       14.0     26.9       3.6          4.4       9.7         ENE
# 2       13.7     23.4       3.6          5.8       3.3          NW
# 3       13.3     15.5      39.8          7.2       9.1          NW
# 4        7.6     16.1       2.8          5.6      10.6         SSE
# ..       ...      ...       ...          ...       ...         ...
# 361      9.0     30.7       0.0          7.6      12.1         NNW
# 362      7.1     28.4       0.0         11.6      12.7           N
# 363     12.5     19.9       0.0          8.4       5.3         ESE
# 364     12.5     26.9       0.0          5.0       7.1          NW
# 365     12.3     30.2       0.0          6.0      12.6          NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0             30.0         SW         NW           6.0  ...           29
# ...

# %%
rows,cols=df.shape

# %%
df.columns
# Out:
# Index(['MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation', 'Sunshine',
#        'WindGustDir', 'WindGustSpeed', 'WindDir9am', 'WindDir3pm',
#        'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm',
#        'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am',
#        'Temp3pm', 'RainToday', 'RISK_MM', 'RainTomorrow'],
#       dtype='object')

# %%
df[["MaxTemp"]]
# Out:
#      MaxTemp
# 0       24.3
# 1       26.9
# 2       23.4
# 3       15.5
# 4       16.1
# ..       ...
# 361     30.7
# 362     28.4
# 363     19.9
# 364     26.9
# 365     30.2
#
# [366 rows x 1 columns]

# %%
df.MaxTemp.max() #min mean std
# Out:
# 35.8

# %%
df.describe()
# Out:
#           MinTemp     MaxTemp    Rainfall  Evaporation    Sunshine  \
# count  366.000000  366.000000  366.000000   366.000000  363.000000
# mean     7.265574   20.550273    1.428415     4.521858    7.909366
# std      6.025800    6.690516    4.225800     2.669383    3.481517
# min     -5.300000    7.600000    0.000000     0.200000    0.000000
# 25%      2.300000   15.025000    0.000000     2.200000    5.950000
# 50%      7.450000   19.650000    0.000000     4.200000    8.600000
# 75%     12.500000   25.500000    0.200000     6.400000   10.500000
# max     20.900000   35.800000   39.800000    13.800000   13.600000
#
#        WindGustSpeed  WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  \
# count     364.000000    359.000000    366.000000   366.000000   366.000000
# mean       39.840659      9.651811     17.986339    72.035519    44.519126
# std        13.059807      7.951929      8.856997    13.137058    16.850947
# ...

# %%
df[df.MaxTemp==df.MaxTemp.max()]
# Out:
#     MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 71     17.5     35.8       0.0          9.4      13.3         SSE
#
#     WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 71           57.0        NNW         NW           6.0  ...           24
#
#     Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# 71       1011.8       1006.5         0         1     24.7     34.5         No
#
#     RISK_MM RainTomorrow
# 71      0.0           No
#
# [1 rows x 22 columns]

# %%
df[["MaxTemp"]][df.MaxTemp==df.MaxTemp.max()]
# Out:
#     MaxTemp
# 71     35.8

# %%
df.set_index('Rainfall',inplace=True) # once u make a particular col as index u can search based on that
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [41], in <cell line: 1>()
# ----> 1 df.set_index('Rainfall',inplace=True) # once u make a particular col as index u can search based on that
#       2 df
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:5494, in DataFrame.set_index(self, keys, drop, append, inplace, verify_integrity)
#    5491                 missing.append(col)
#    5493 if missing:
# ...

# %%
df.loc[0.0] #all the records didn't rain
# Out:
#           MinTemp  Evaporation  Sunshine WindGustDir  WindGustSpeed  \
# Rainfall
# 0.0           8.0          3.4       6.3          NW           30.0
# 0.0           6.2          5.8       8.2          SE           44.0
# 0.0           8.3          5.6       4.6           E           41.0
# 0.0           8.8          4.0       4.1           S           48.0
# 0.0           9.1          4.2      11.9           N           30.0
# ...           ...          ...       ...         ...            ...
# 0.0           9.0          7.6      12.1         NNW           76.0
# 0.0           7.1         11.6      12.7           N           48.0
# 0.0          12.5          8.4       5.3         ESE           43.0
# 0.0          12.5          5.0       7.1          NW           46.0
# 0.0          12.3          6.0      12.6          NW           78.0
#
#          WindDir9am WindDir3pm  WindSpeed9am  WindSpeed3pm  Humidity9am  \
# Rainfall
# ...

# %%
df.to_csv("modified_weather.csv")

# %%
data.to_excel( "modified_data.xlsx", sheet_name='Sheet1', \*\*kwargs )
# Out:
#   Input In [53]
#     data.to_excel( "modified_data.xlsx", sheet_name='Sheet1', \*\*kwargs )
#                                                                ^
# SyntaxError: unexpected character after line continuation character
